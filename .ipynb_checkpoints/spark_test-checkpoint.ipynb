# %%
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import hour, weekofyear, date_format,dayofweek
from pyspark.sql.functions import year,month, dayofmonth
from pyspark.sql.functions import monotonically_increasing_id
#from pyspark.sql.functions import to_timestamp
from pyspark.sql.types import StructType, StructField, DoubleType, StringType
from pyspark.sql.types import IntegerType, DateType

# %%
pd.set_option('display.max_colwidth', -1)
#from pyspark import SparkContext
#sc = SparkContext()

# %%
def create_spark_session():
    """Creates SparkSession. General configurarion
    of the script.
    """
    spark = SparkSession \
        .builder \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
        .getOrCreate()
    return spark

# %%
spark=create_spark_session()
input_data = "/home/gari/Desktop/final_project/input_data/arxiv-metadata-oai-snapshot.json"
output_data="/home/gari/Desktop/final_project/parquet_area/"

# %%
df = spark.read.json(input_data)

# %%
df=df.limit(5000)

# %%
df.limit(50).toPandas()
# Out:
#                                              abstract  \
# 0     A fully differential calculation in perturba...
# 1     We describe a new algorithm, the $(k,\ell)$-...
# 2     The evolution of Earth-Moon system is descri...
# 3     We show that a determinant of Stirling cycle...
# 4     In this paper we show how to compute the $\L...
# 5     We study the two-particle wave function of p...
# 6     A rather non-standard quantum representation...
# 7     A general formulation was developed to repre...
# 8     We discuss the results from the combined IRA...
# 9     Partial cubes are isometric subgraphs of hyp...
# 10    In this paper we present an algorithm for co...
# 11    Recently, Bruinier and Ono classified cusp f...
# 12    Serre obtained the p-adic limit of the integ...
# 13    In this article we discuss a relation betwee...
# 14    The pure spinor formulation of the ten-dimen...
# 15    In this work, we evaluate the lifetimes of t...
# 16    Results from spectroscopic observations of t...
# 17    We give a prescription for how to compute th...
# 18    In this note we give a new method for gettin...
# 19    The shape of the hadronic form factor f+(q2)...
# 20    Spatiotemporal pattern formation in a produc...
# 21    We present Lie group integrators for nonline...
# 22    The very nature of the solar chromosphere, i...
# 23    The formation of quasi-2D spin-wave waveform...
# 24    We present recent advances in understanding ...
# 25    Zero-divisors (ZDs) derived by Cayley-Dickso...
# 26    We describe a peculiar fine structure acquir...
# 27    We prove pfaffian and hafnian versions of Li...
# 28    In $\XQM$, a quark can emit Goldstone bosons...
# 29    We investigate the effect of tuning the phon...
# 30    We show that crystal can trap a broad (x, x'...
# 31    We analyze the possibility of probing non-st...
# 32    We performed a rigorous theoretical converge...
# 33    This is a supplement to the paper arXiv:q-bi...
# 34    We propose an extrapolation technique that a...
# 35    The multisite phosphorylation-dephosphorylat...
# 36    In this manuscript we investigate the capabi...
# 37    We present a review of the discrete dipole a...
# 38    The quadratic pion scalar radius, \la r^2\ra...
# 39    As in the cases of freeness and monotonic in...
# 40    We formulate a quantum generalization of the...
# 41    It is outlined the possibility to extend the...
# 42    We construct a system of nonequilibrium entr...
# 43    We present a theoretical framework for plasm...
# 44    This paper considers the propagation of shal...
# 45    In a quantum mechanical model, Diosi, Feldma...
# 46    The intelligent acoustic emission locator is...
# 47    We report on the analysis of selected single...
# 48    We present an algorithm that produces the cl...
# 49    Part I describes an intelligent acoustic emi...
#
#                                               authors  \
# 0   C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                     Ileana Streinu and Louis Theran
# 2                                         Hongjun Pan
# 3                                        David Callan
# 4            Wael Abu-Shammala and Alberto Torchinsky
# 5                            Y. H. Pong and C. K. Law
# 6   Alejandro Corichi, Tatjana Vukasinac and Jose ...
# 7                                     Damian C. Swift
# 8   Paul Harvey, Bruno Merin, Tracy L. Huard, Luis...
# 9                                  Sergei Ovchinnikov
# 10             Clifton Cunningham and Lassina Dembele
# 11                                        Dohoon Choi
# 12                      Dohoon Choi and YoungJu Choie
# 13                                       Koichi Fujii
# 14                                    Christian Stahn
# 15  Chao-Hsi Chang, Tong Li, Xue-Qian Li and Yu-Mi...
# 16  Nceba Mhlahlo, David H. Buckley, Vikram S. Dhi...
# 17                                 Andreas Gustavsson
# 18                                        Norio Konno
# 19          The BABAR Collaboration, B. Aubert, et al
# 20  Vanessa Casagrande, Yuichi Togashi, Alexander ...
# 21                   Simon J.A. Malham and Anke Wiese
# 22      M. A. Loukitcheva, S. K. Solanki and S. White
# 23        A.A. Serga, M. Kostylev, and B. Hillebrands
# 24  A. S. Mishchenko (1 and 2) and N. Nagaosa (1 a...
# 25                            Robert P. C. de Marrais
# 26  M. O. Goerbig, J.-N. Fuchs, K. Kechedzhi, Vlad...
# 27                                 P\'eter E. Frenkel
# 28          Zhan Shu, Xiao-Lin Chen and Wei-Zhen Deng
# 29                       J.P.Hague and N.d'Ambrumenil
# 30                   V. M. Biryukov (Serpukhov, IHEP)
# 31   A. Esteban-Pretel, R. Tom\`as and J. W. F. Valle
# 32  Maxim A. Yurkin, Valeri P. Maltsev, Alfons G. ...
# 33                                     Vasily Ogryzko
# 34  Maxim A. Yurkin, Valeri P. Maltsev, Alfons G. ...
# 35                  Liming Wang and Eduardo D. Sontag
# 36  Maxim A. Yurkin, Valeri P. Maltsev, Alfons G. ...
# 37                Maxim A. Yurkin, Alfons G. Hoekstra
# 38                        Jose A. Oller and Luis Roca
# 39                                         Mihai Popa
# 40                                  Debashish Goswami
# 41                                     Ignazio Licata
# 42            R.A. Brownlee, A.N. Gorban, J. Levesley
# 43  A. A. Schekochihin (Oxford), S. C. Cowley (Cul...
# 44          G.A. El, R.H.J. Grimshaw, A.M. Kamchatnov
# 45                    I. Csiszar, F. Hiai and D. Petz
# 46                             T. Kosel and I. Grabec
# 47  Alexander Stroeer, John Veitch, Christian Roev...
# 48                                     Mikkel {\O}bro
# 49                             T. Kosel and I. Grabec
#
#                                        authors_parsed  \
# 0   [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 1            [[Streinu, Ileana, ], [Theran, Louis, ]]
# 2                                  [[Pan, Hongjun, ]]
# 3                                 [[Callan, David, ]]
# 4   [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]
# 5                   [[Pong, Y. H., ], [Law, C. K., ]]
# 6   [[Corichi, Alejandro, ], [Vukasinac, Tatjana, ...
# 7                              [[Swift, Damian C., ]]
# 8   [[Harvey, Paul, ], [Merin, Bruno, ], [Huard, T...
# 9                           [[Ovchinnikov, Sergei, ]]
# 10    [[Cunningham, Clifton, ], [Dembele, Lassina, ]]
# 11                                 [[Choi, Dohoon, ]]
# 12             [[Choi, Dohoon, ], [Choie, YoungJu, ]]
# 13                                [[Fujii, Koichi, ]]
# 14                             [[Stahn, Christian, ]]
# 15  [[Chang, Chao-Hsi, ], [Li, Tong, ], [Li, Xue-Q...
# 16  [[Mhlahlo, Nceba, ], [Buckley, David H., ], [D...
# 17                          [[Gustavsson, Andreas, ]]
# 18                                 [[Konno, Norio, ]]
# 19    [[The BABAR Collaboration, , ], [Aubert, B., ]]
# 20  [[Casagrande, Vanessa, ], [Togashi, Yuichi, ],...
# 21         [[Malham, Simon J. A., ], [Wiese, Anke, ]]
# 22  [[Loukitcheva, M. A., ], [Solanki, S. K., ], [...
# 23  [[Serga, A. A., ], [Kostylev, M., ], [Hillebra...
# 24  [[Mishchenko, A. S., , 1 and 2], [Nagaosa, N.,...
# 25                     [[de Marrais, Robert P. C., ]]
# 26  [[Goerbig, M. O., ], [Fuchs, J. -N., ], [Keche...
# 27                            [[Frenkel, Péter E., ]]
# 28  [[Shu, Zhan, ], [Chen, Xiao-Lin, ], [Deng, Wei...
# 29           [[Hague, J. P., ], [d'Ambrumenil, N., ]]
# 30             [[Biryukov, V. M., , Serpukhov, IHEP]]
# 31  [[Esteban-Pretel, A., ], [Tomàs, R., ], [Valle...
# 32  [[Yurkin, Maxim A., ], [Maltsev, Valeri P., ],...
# 33                              [[Ogryzko, Vasily, ]]
# 34  [[Yurkin, Maxim A., ], [Maltsev, Valeri P., ],...
# 35         [[Wang, Liming, ], [Sontag, Eduardo D., ]]
# 36  [[Yurkin, Maxim A., ], [Maltsev, Valeri P., ],...
# 37    [[Yurkin, Maxim A., ], [Hoekstra, Alfons G., ]]
# 38               [[Oller, Jose A., ], [Roca, Luis, ]]
# 39                                  [[Popa, Mihai, ]]
# 40                           [[Goswami, Debashish, ]]
# 41                              [[Licata, Ignazio, ]]
# 42  [[Brownlee, R. A., ], [Gorban, A. N., ], [Leve...
# 43  [[Schekochihin, A. A., , Oxford], [Cowley, S. ...
# 44  [[El, G. A., ], [Grimshaw, R. H. J., ], [Kamch...
# 45      [[Csiszar, I., ], [Hiai, F., ], [Petz, D., ]]
# 46                    [[Kosel, T., ], [Grabec, I., ]]
# 47  [[Stroeer, Alexander, ], [Veitch, John, ], [Ro...
# 48                                 [[Øbro, Mikkel, ]]
# 49                    [[Kosel, T., ], [Grabec, I., ]]
#
#                                            categories  \
# 0                                              hep-ph
# 1                                       math.CO cs.CG
# 2                                      physics.gen-ph
# 3                                             math.CO
# 4                                     math.CA math.FA
# 5                                   cond-mat.mes-hall
# 6                                               gr-qc
# 7                                   cond-mat.mtrl-sci
# 8                                            astro-ph
# 9                                             math.CO
# 10                                    math.NT math.AG
# 11                                            math.NT
# 12                                            math.NT
# 13                                    math.CA math.AT
# 14                                             hep-th
# 15                                             hep-ph
# 16                                           astro-ph
# 17                                             hep-th
# 18                                    math.PR math.AG
# 19                                             hep-ex
# 20                   nlin.PS physics.chem-ph q-bio.MN
# 21                                            math.NA
# 22                                           astro-ph
# 23                                            nlin.PS
# 24                 cond-mat.str-el cond-mat.stat-mech
# 25                                            math.RA
# 26                                  cond-mat.mes-hall
# 27                                    math.CA math.PR
# 28                                             hep-ph
# 29                                    cond-mat.str-el
# 30                                             hep-ph
# 31                                             hep-ph
# 32                     physics.optics physics.comp-ph
# 33                         q-bio.PE q-bio.CB quant-ph
# 34                     physics.optics physics.comp-ph
# 35                                  q-bio.QM q-bio.MN
# 36                     physics.optics physics.comp-ph
# 37                     physics.optics physics.comp-ph
# 38                             hep-ph hep-lat nucl-th
# 39                                    math.OA math.FA
# 40                            math.QA math-ph math.MP
# 41                            physics.gen-ph quant-ph
# 42               cond-mat.stat-mech cond-mat.mtrl-sci
# 43  astro-ph nlin.CD physics.plasm-ph physics.spac...
# 44                                    nlin.PS nlin.SI
# 45                             quant-ph cs.IT math.IT
# 46                                        cs.NE cs.AI
# 47                                     gr-qc astro-ph
# 48                                            math.CO
# 49                                        cs.NE cs.AI
#
#                                              comments  \
# 0             37 pages, 15 figures; published version
# 1               To appear in Graphs and Combinatorics
# 2                                 23 pages, 3 figures
# 3                                            11 pages
# 4                                                None
# 5                 6 pages, 4 figures, accepted by PRA
# 6   16 pages, no figures. Typos corrected to match...
# 7                                   Minor corrections
# 8                                                None
# 9                                36 pages, 17 figures
# 10  14 pages; title changed; to appear in Experime...
# 11                                               None
# 12                                               None
# 13                                 18 pages, 1 figure
# 14  22 pages; signs and coefficients adjusted for ...
# 15                    17 pages, 3 figures and 1 table
# 16  10 pages, 11 figures (figures 3, 4, 7 and 8 at...
# 17  20 pages, v2: an overall sign and typos corrected
# 18                         6 pages, Journal-ref added
# 19  21 pages, 13 postscript figures, submitted to ...
# 20                                 5 pages, 4 figures
# 21                                20 pages, 4 figures
# 22  4 pages, 2 figures, to appear in the proceedin...
# 23  First appeared in Prof. B. Hillebrands' resear...
# 24  41 pages, 13 figures, in "Polarons in Advanced...
# 25  31 pp. Second of 3-part "theorem/proof" exposi...
# 26  4 pages, 2 figures; mistakes due to an erroneo...
# 27                                           10 pages
# 28                                               None
# 29    Reprint to improve access. 13 pages, 6 figures.
# 30                                11 pages, 3 figures
# 31          21 pages, 12 figures, 17 postscript files
# 32                                23 pages, 5 figures
# 33                                            5 pages
# 34                                17 pages, 8 figures
# 35  Resubmit with new results on the upper bound o...
# 36                               13 pages, 10 figures
# 37                                 36 pages, 1 figure
# 38  18 pages, 3 figures. Some rewriting in the pre...
# 39                           Final version, published
# 40  improvements: (i) more general approach throug...
# 41                                 12 pages,3 figures
# 42                       30 pages, 9 figures, 1 table
# 43  aastex using emulateapj, 65 pages, 10 figures;...
# 44         accepted for publication in J. Fluid Mech.
# 45                               LATEX file, 11 pages
# 46          5 pages, 5 eps figures, uses IEEEtran.cls
# 47  GWDAW-11 proceeding, submitted to CQG, 10 page...
# 48                                          17 pages.
# 49          5 pages, 7 eps figures, uses IEEEtran.cls
#
#                                  doi         id  \
# 0         10.1103/PhysRevD.76.013009  0704.0001
# 1                               None  0704.0002
# 2                               None  0704.0003
# 3                               None  0704.0004
# 4                               None  0704.0005
# 5         10.1103/PhysRevA.75.043613  0704.0006
# 6         10.1103/PhysRevD.76.044016  0704.0007
# 7                  10.1063/1.2975338  0704.0008
# 8                     10.1086/518646  0704.0009
# 9                               None  0704.0010
# 10                              None  0704.0011
# 11                              None  0704.0012
# 12                              None  0704.0013
# 13                              None  0704.0014
# 14     10.1088/1126-6708/2007/05/034  0704.0015
# 15         10.1088/0253-6102/49/4/38  0704.0016
# 16  10.1111/j.1365-2966.2007.11762.x  0704.0017
# 17                              None  0704.0018
# 18                              None  0704.0019
# 19        10.1103/PhysRevD.76.052005  0704.0020
# 20     10.1103/PhysRevLett.99.048301  0704.0021
# 21                              None  0704.0022
# 22         10.1007/s10509-007-9626-1  0704.0023
# 23                              None  0704.0024
# 24      10.1007/978-1-4020-6348-0_12  0704.0025
# 25                              None  0704.0026
# 26     10.1103/PhysRevLett.99.087402  0704.0027
# 27                              None  0704.0028
# 28        10.1103/PhysRevD.75.094018  0704.0029
# 29         10.1007/s10909-005-6013-6  0704.0030
# 30    10.1016/j.physletb.2007.10.051  0704.0031
# 31        10.1103/PhysRevD.76.053001  0704.0032
# 32           10.1364/JOSAA.23.002578  0704.0033
# 33                              None  0704.0034
# 34           10.1364/JOSAA.23.002592  0704.0035
# 35                              None  0704.0036
# 36       10.1016/j.jqsrt.2007.01.033  0704.0037
# 37       10.1016/j.jqsrt.2007.01.034  0704.0038
# 38    10.1016/j.physletb.2007.06.023  0704.0039
# 39                              None  0704.0040
# 40         10.1007/s00220-008-0461-1  0704.0041
# 41                              None  0704.0042
# 42       10.1016/j.physa.2007.09.031  0704.0043
# 43       10.1088/0067-0049/182/1/310  0704.0044
# 44         10.1017/S0022112007006817  0704.0045
# 45                 10.1063/1.2779138  0704.0046
# 46                              None  0704.0047
# 47       10.1088/0264-9381/24/19/S17  0704.0048
# 48                              None  0704.0049
# 49                              None  0704.0050
#
#                                           journal-ref  \
# 0                            Phys.Rev.D76:013009,2007
# 1                                                None
# 2                                                None
# 3                                                None
# 4           Illinois J. Math. 52 (2008) no.2, 681-689
# 5                                                None
# 6                            Phys.Rev.D76:044016,2007
# 7   Journal of Applied Physics, vol 104, 073536 (2...
# 8                      Astrophys.J.663:1149-1173,2007
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                 JHEP 0705:034,2007
# 15                 Commun.Theor.Phys.49:993-1000,2008
# 16            Mon.Not.Roy.Astron.Soc.378:211-220,2007
# 17                                               None
# 18           RIMS Kokyuroku, No.1551, pp.57-62 (2007)
# 19                           Phys.Rev.D76:052005,2007
# 20                 Phys. Rev. Lett. 99, 048301 (2007)
# 21                                               None
# 22               Astrophys.Space Sci.313:197-200,2008
# 23                                               None
# 24                                               None
# 25                                               None
# 26                 Phys. Rev. Lett. 99, 087402 (2007)
# 27        Math. Res. Lett. 15 (2008), no. 2, 351--358
# 28                           Phys.Rev.D75:094018,2007
# 29        J. Low. Temp. Phys. Vol. 140 pp77-89 (2005)
# 30                           Phys.Lett.B658:7-12,2007
# 31                           Phys.Rev.D76:053001,2007
# 32            J.Opt.Soc.Am.A 23(10): 2578-2591 (2006)
# 33                                               None
# 34            J.Opt.Soc.Am.A 23(10): 2592-2601 (2006)
# 35                                               None
# 36  J.Quant.Spectrosc.Radiat.Transf. 106, 546-557 ...
# 37  J.Quant.Spectrosc.Radiat.Transf. 106, 558-589 ...
# 38                        Phys.Lett.B651:139-146,2007
# 39                                               None
# 40                                               None
# 41                                               None
# 42  Physica A, V. 387, Issues 2-3 (2008), Pages 38...
# 43                               ApJS 182, 310 (2009)
# 44                 J. Fluid Mech. 585, 213-244 (2007)
# 45                   J. Math. Phys. 48(2007), 092102.
# 46                                               None
# 47                 Class.Quant.Grav.24:S541-S550,2007
# 48                                               None
# 49                                               None
#
#                                               license  \
# 0                                                None
# 1   http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   http://arxiv.org/licenses/nonexclusive-distrib...
# 8                                                None
# 9                                                None
# 10  http://arxiv.org/licenses/nonexclusive-distrib...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  http://arxiv.org/licenses/nonexclusive-distrib...
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39  http://arxiv.org/licenses/nonexclusive-distrib...
# 40                                               None
# 41                                               None
# 42                                               None
# 43  http://arxiv.org/licenses/nonexclusive-distrib...
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#                                             report-no  \
# 0                                    ANL-HEP-PR-07-12
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                        IGPG-07/03-2
# 7                     LA-UR-07-2051, LLNL-JRNL-410358
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                   BABAR-PUB-07/015, SLAC-PUB-12417
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41  Published in Systemics of Emergence. Research ...
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#                   submitter  \
# 0            Pavel Nadolsky
# 1              Louis Theran
# 2               Hongjun Pan
# 3              David Callan
# 4        Alberto Torchinsky
# 5              Yue Hin Pong
# 6         Alejandro Corichi
# 7              Damian Swift
# 8               Paul Harvey
# 9        Sergei Ovchinnikov
# 10       Clifton Cunningham
# 11              Dohoon Choi
# 12              Dohoon Choi
# 13             Koichi Fujii
# 14          Christian Stahn
# 15                  Li Tong
# 16            Nceba Mhlahlo
# 17       Andreas Gustavsson
# 18              Norio Konno
# 19          Patrick Roudeau
# 20           Yuichi Togashi
# 21             Simon Malham
# 22        Maria Loukitcheva
# 23         Mikhail Kostylev
# 24      Andrei Mishchenko S
# 25  Robert P. C. de Marrais
# 26            M. O. Goerbig
# 27       P\'eter E. Frenkel
# 28             Weizhen Deng
# 29                Jim Hague
# 30       Valery M. Biryukov
# 31    Andreu Esteban-Pretel
# 32          Maxim A. Yurkin
# 33         Vasily Ogryzko V
# 34          Maxim A. Yurkin
# 35        Eduardo D. Sontag
# 36          Maxim A. Yurkin
# 37          Maxim A. Yurkin
# 38       Jose Antonio Oller
# 39               Mihai Popa
# 40        Debashish Goswami
# 41           Ignazio Licata
# 42         Alexander Gorban
# 43   Alexander Schekochihin
# 44         A. M. Kamchatnov
# 45               Denes Petz
# 46              Igor Grabec
# 47        Alexander Stroeer
# 48           Mikkel {\O}bro
# 49              Igor Grabec
#
#                                                 title update_date  \
# 0   Calculation of prompt diphoton production cros...  2008-11-26
# 1            Sparsity-certifying Graph Decompositions  2008-12-13
# 2   The evolution of the Earth-Moon system based o...  2008-01-13
# 3   A determinant of Stirling cycle numbers counts...  2007-05-23
# 4   From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...  2013-10-15
# 5   Bosonic characters of atomic Cooper pairs acro...  2015-05-13
# 6   Polymer Quantum Mechanics and its Continuum Limit  2008-11-26
# 7   Numerical solution of shock and ramp compressi...  2009-02-05
# 8   The Spitzer c2d Survey of Large, Nearby, Inste...  2010-03-18
# 9   Partial cubes: structures, characterizations, ...  2007-05-23
# 10  Computing genus 2 Hilbert-Siegel modular forms...  2008-08-20
# 11  Distribution of integral Fourier Coefficients ...  2007-05-23
# 12  $p$-adic Limit of Weakly Holomorphic Modular F...  2008-05-26
# 13             Iterated integral and the loop product  2009-09-29
# 14  Fermionic superstring loop amplitudes in the p...  2009-11-13
# 15                 Lifetime of doubly charmed baryons  2008-12-18
# 16  Spectroscopic Observations of the Intermediate...  2009-06-23
# 17    In quest of a generalized Callias index theorem  2007-05-23
# 18  Approximation for extinction probability of th...  2007-06-23
# 19  Measurement of the Hadronic Form Factor in D0 ...  2015-06-30
# 20  Molecular Synchronization Waves in Arrays of A...  2007-07-24
# 21                   Stochastic Lie group integrators  2007-10-16
# 22  ALMA as the ideal probe of the solar chromosphere  2009-06-23
# 23  Formation of quasi-solitons in transverse conf...  2007-05-30
# 24  Spectroscopic Properties of Polarons in Strong...  2015-05-13
# 25  Placeholder Substructures II: Meta-Fractals, M...  2007-11-22
# 26  Filling-Factor-Dependent Magnetophonon Resonan...  2009-09-24
# 27  Pfaffians, hafnians and products of real linea...  2014-07-31
# 28  Understanding the Flavor Symmetry Breaking and...  2010-04-23
# 29  Tuning correlation effects with electron-phono...  2015-05-13
# 30  Crystal channeling of LHC forward protons with...  2008-11-26
# 31  Probing non-standard neutrino interactions wit...  2008-11-26
# 32  Convergence of the discrete dipole approximati...  2008-07-29
# 33  Origin of adaptive mutants: a quantum measurem...  2007-05-23
# 34  Convergence of the discrete dipole approximati...  2008-07-29
# 35  A remark on the number of steady states in a m...  2011-11-09
# 36  The discrete dipole approximation for simulati...  2007-05-23
# 37  The discrete dipole approximation: an overview...  2009-09-29
# 38  Scalar radius of the pion and zeros in the for...  2008-11-26
# 39  Multilinear function series in conditionally f...  2008-09-05
# 40  Quantum Group of Isometries in Classical and N...  2009-11-13
# 41  General System theory, Like-Quantum Semantics ...  2010-04-26
# 42  Nonequilibrium entropy limiters in lattice Bol...  2007-11-19
# 43  Astrophysical gyrokinetics: kinetic and fluid ...  2015-05-13
# 44  Evolution of solitary waves and undular bores ...  2007-09-23
# 45  A limit relation for entropy and channel capac...  2009-11-13
# 46  Intelligent location of simultaneously active ...  2009-09-29
# 47  Inference on white dwarf binary systems using ...  2008-11-26
# 48  An algorithm for the classification of smooth ...  2007-05-23
# 49  Intelligent location of simultaneously active ...  2007-05-23
#
#                                              versions
# 0   [(Mon, 2 Apr 2007 19:18:42 GMT, v1), (Tue, 24 ...
# 1   [(Sat, 31 Mar 2007 02:26:18 GMT, v1), (Sat, 13...
# 2   [(Sun, 1 Apr 2007 20:46:54 GMT, v1), (Sat, 8 D...
# 3               [(Sat, 31 Mar 2007 03:16:14 GMT, v1)]
# 4                [(Mon, 2 Apr 2007 18:09:58 GMT, v1)]
# 5               [(Sat, 31 Mar 2007 04:24:59 GMT, v1)]
# 6   [(Sat, 31 Mar 2007 04:27:22 GMT, v1), (Wed, 22...
# 7   [(Sat, 31 Mar 2007 04:47:20 GMT, v1), (Thu, 10...
# 8                [(Mon, 2 Apr 2007 19:41:34 GMT, v1)]
# 9               [(Sat, 31 Mar 2007 05:10:16 GMT, v1)]
# 10  [(Sat, 31 Mar 2007 05:32:49 GMT, v1), (Tue, 19...
# 11              [(Sat, 31 Mar 2007 05:48:51 GMT, v1)]
# 12  [(Sat, 31 Mar 2007 06:21:49 GMT, v1), (Mon, 26...
# 13               [(Sun, 1 Apr 2007 12:04:13 GMT, v1)]
# 14  [(Mon, 2 Apr 2007 18:10:09 GMT, v1), (Mon, 10 ...
# 15              [(Sat, 31 Mar 2007 07:04:26 GMT, v1)]
# 16              [(Sat, 31 Mar 2007 07:38:48 GMT, v1)]
# 17  [(Mon, 2 Apr 2007 08:58:27 GMT, v1), (Sat, 21 ...
# 18  [(Sat, 31 Mar 2007 08:12:35 GMT, v1), (Sat, 23...
# 19              [(Sat, 31 Mar 2007 09:49:10 GMT, v1)]
# 20  [(Sat, 31 Mar 2007 12:57:59 GMT, v1), (Tue, 24...
# 21  [(Sat, 31 Mar 2007 11:05:53 GMT, v1), (Tue, 16...
# 22              [(Sat, 31 Mar 2007 11:42:13 GMT, v1)]
# 23              [(Sat, 31 Mar 2007 11:44:22 GMT, v1)]
# 24               [(Mon, 2 Apr 2007 12:02:36 GMT, v1)]
# 25  [(Sat, 31 Mar 2007 12:24:06 GMT, v1), (Sun, 8 ...
# 26  [(Mon, 2 Apr 2007 19:17:14 GMT, v1), (Mon, 9 A...
# 27  [(Mon, 2 Apr 2007 15:36:29 GMT, v1), (Tue, 26 ...
# 28  [(Sat, 31 Mar 2007 14:10:06 GMT, v1), (Thu, 26...
# 29              [(Sat, 31 Mar 2007 14:14:18 GMT, v1)]
# 30              [(Sat, 31 Mar 2007 14:14:46 GMT, v1)]
# 31               [(Mon, 2 Apr 2007 18:35:33 GMT, v1)]
# 32              [(Sat, 31 Mar 2007 15:34:25 GMT, v1)]
# 33              [(Sat, 31 Mar 2007 15:36:48 GMT, v1)]
# 34              [(Sat, 31 Mar 2007 15:52:56 GMT, v1)]
# 35  [(Sat, 31 Mar 2007 15:55:50 GMT, v1), (Fri, 20...
# 36              [(Sat, 31 Mar 2007 16:06:05 GMT, v1)]
# 37              [(Sat, 31 Mar 2007 16:25:01 GMT, v1)]
# 38  [(Sat, 31 Mar 2007 17:06:06 GMT, v1), (Wed, 25...
# 39  [(Sat, 31 Mar 2007 17:05:04 GMT, v1), (Wed, 18...
# 40  [(Sat, 31 Mar 2007 21:04:54 GMT, v1), (Tue, 10...
# 41              [(Sat, 31 Mar 2007 17:28:35 GMT, v1)]
# 42              [(Sat, 31 Mar 2007 17:31:12 GMT, v1)]
# 43  [(Sat, 31 Mar 2007 17:47:54 GMT, v1), (Sat, 24...
# 44              [(Sat, 31 Mar 2007 18:09:02 GMT, v1)]
# 45               [(Sun, 1 Apr 2007 16:37:36 GMT, v1)]
# 46               [(Sun, 1 Apr 2007 13:06:50 GMT, v1)]
# 47  [(Sat, 31 Mar 2007 19:17:47 GMT, v1), (Tue, 3 ...
# 48               [(Mon, 2 Apr 2007 09:23:25 GMT, v1)]
# 49               [(Sun, 1 Apr 2007 18:53:13 GMT, v1)]

# %%
df.select('versions').printSchema()
# Out:
# root
#  |-- versions: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- version: string (nullable = true)

# %%
df.selectExpr("versions","explode(versions)").show(2)
# Out:
# +--------------------+--------------------+
# |            versions|                 col|
# +--------------------+--------------------+
# |[[Mon, 2 Apr 2007...|[Mon, 2 Apr 2007 ...|
# |[[Mon, 2 Apr 2007...|[Tue, 24 Jul 2007...|
# +--------------------+--------------------+
# only showing top 2 rows

# %%
df.selectExpr("versions").limit(10).toPandas()
# Out:
#                                                                                                          versions
# 0  [(Mon, 2 Apr 2007 19:18:42 GMT, v1), (Tue, 24 Jul 2007 20:10:27 GMT, v2)]
# 1  [(Sat, 31 Mar 2007 02:26:18 GMT, v1), (Sat, 13 Dec 2008 17:26:00 GMT, v2)]
# 2  [(Sun, 1 Apr 2007 20:46:54 GMT, v1), (Sat, 8 Dec 2007 23:47:24 GMT, v2), (Sun, 13 Jan 2008 00:36:28 GMT, v3)]
# 3  [(Sat, 31 Mar 2007 03:16:14 GMT, v1)]
# 4  [(Mon, 2 Apr 2007 18:09:58 GMT, v1)]
# 5  [(Sat, 31 Mar 2007 04:24:59 GMT, v1)]
# 6  [(Sat, 31 Mar 2007 04:27:22 GMT, v1), (Wed, 22 Aug 2007 22:42:11 GMT, v2)]
# 7  [(Sat, 31 Mar 2007 04:47:20 GMT, v1), (Thu, 10 Apr 2008 08:42:28 GMT, v2), (Tue, 1 Jul 2008 18:54:28 GMT, v3)]
# 8  [(Mon, 2 Apr 2007 19:41:34 GMT, v1)]
# 9  [(Sat, 31 Mar 2007 05:10:16 GMT, v1)]

# %%
df.selectExpr("versions","explode(versions)").limit(10).toPandas()
# Out:
#                                                                                                         versions  \
# 0  [(Mon, 2 Apr 2007 19:18:42 GMT, v1), (Tue, 24 Jul 2007 20:10:27 GMT, v2)]
# 1  [(Mon, 2 Apr 2007 19:18:42 GMT, v1), (Tue, 24 Jul 2007 20:10:27 GMT, v2)]
# 2  [(Sat, 31 Mar 2007 02:26:18 GMT, v1), (Sat, 13 Dec 2008 17:26:00 GMT, v2)]
# 3  [(Sat, 31 Mar 2007 02:26:18 GMT, v1), (Sat, 13 Dec 2008 17:26:00 GMT, v2)]
# 4  [(Sun, 1 Apr 2007 20:46:54 GMT, v1), (Sat, 8 Dec 2007 23:47:24 GMT, v2), (Sun, 13 Jan 2008 00:36:28 GMT, v3)]
# 5  [(Sun, 1 Apr 2007 20:46:54 GMT, v1), (Sat, 8 Dec 2007 23:47:24 GMT, v2), (Sun, 13 Jan 2008 00:36:28 GMT, v3)]
# 6  [(Sun, 1 Apr 2007 20:46:54 GMT, v1), (Sat, 8 Dec 2007 23:47:24 GMT, v2), (Sun, 13 Jan 2008 00:36:28 GMT, v3)]
# 7  [(Sat, 31 Mar 2007 03:16:14 GMT, v1)]
# 8  [(Mon, 2 Apr 2007 18:09:58 GMT, v1)]
# 9  [(Sat, 31 Mar 2007 04:24:59 GMT, v1)]
#
#                                    col
# 0  (Mon, 2 Apr 2007 19:18:42 GMT, v1)
# 1  (Tue, 24 Jul 2007 20:10:27 GMT, v2)
# 2  (Sat, 31 Mar 2007 02:26:18 GMT, v1)
# 3  (Sat, 13 Dec 2008 17:26:00 GMT, v2)
# 4  (Sun, 1 Apr 2007 20:46:54 GMT, v1)
# 5  (Sat, 8 Dec 2007 23:47:24 GMT, v2)
# 6  (Sun, 13 Jan 2008 00:36:28 GMT, v3)
# 7  (Sat, 31 Mar 2007 03:16:14 GMT, v1)
# 8  (Mon, 2 Apr 2007 18:09:58 GMT, v1)
# 9  (Sat, 31 Mar 2007 04:24:59 GMT, v1)

# %%
import datetime
estDF.select("start_date", date_format("start_date", 'dd/MM/yyyy').alias("dt_format")).show()

# %%
get_hour = udf(lambda x: dayofmonth(x))

# %%
test_df = df_versions.withColumn("time", dayofmonth((df_versions.created)))

# %%
df_versions.select("created", date_format("created", 'dd/MM/yyyy').alias("dt_format")).show()
# Out:
# +--------------------+---------+
# |             created|dt_format|
# +--------------------+---------+
# |Mon, 2 Apr 2007 1...|     null|
# |Tue, 24 Jul 2007 ...|     null|
# |Sat, 31 Mar 2007 ...|     null|
# |Sat, 13 Dec 2008 ...|     null|
# |Sun, 1 Apr 2007 2...|     null|
# |Sat, 8 Dec 2007 2...|     null|
# |Sun, 13 Jan 2008 ...|     null|
# |Sat, 31 Mar 2007 ...|     null|
# |Mon, 2 Apr 2007 1...|     null|
# |Sat, 31 Mar 2007 ...|     null|
# |Sat, 31 Mar 2007 ...|     null|
# |Wed, 22 Aug 2007 ...|     null|
# |Sat, 31 Mar 2007 ...|     null|
# |Thu, 10 Apr 2008 ...|     null|
# |Tue, 1 Jul 2008 1...|     null|
# |Mon, 2 Apr 2007 1...|     null|
# |Sat, 31 Mar 2007 ...|     null|
# |Sat, 31 Mar 2007 ...|     null|
# |Tue, 19 Aug 2008 ...|     null|
# |Wed, 20 Aug 2008 ...|     null|
# +--------------------+---------+
# only showing top 20 rows

# %%
from datetime import datetime
import pytz
from pyspark.sql.functions import udf, to_date, to_utc_timestamp

## Converting date string format
def getDate(x):
    if x is not None:
        return str(datetime.strptime(x,'%a %b %d %H:%M:%S +0000 %Y').replace(tzinfo=pytz.UTC).strftime("%Y-%m-%d %H:%M:%S"))
    else:
        return None

## UDF declaration
date_fn = udf(getDate, StringType())

## Converting datatype in spark dataframe
df_versions = df_versions.withColumn("created", to_utc_timestamp(date_fn("created"),"UTC"))

# %%
from pyspark.sql.functions import to_timestamp, date_format,from_unixtime,unix_timestamp

# %%
df_versions = df_versions.withColumn("date", to_utc_timestamp(date_fn("created"),"UTC"))

# %%
df_versions=df.selectExpr("id","versions","explode(versions) as info_versions")
df_versions=df_versions.withColumn("created", col("info_versions.created"))
df_versions=df_versions.withColumn("version", col("info_versions.version"))
df_versions=df_versions.selectExpr("id","created","version")
df_versions.show(3)
# Out:
# +---------+--------------------+-------+
# |       id|             created|version|
# +---------+--------------------+-------+
# |0704.0001|Mon, 2 Apr 2007 1...|     v1|
# |0704.0001|Tue, 24 Jul 2007 ...|     v2|
# |0704.0002|Sat, 31 Mar 2007 ...|     v1|
# +---------+--------------------+-------+
# only showing top 3 rows

# %%
df_abstracts=df.select("id","abstract")
df_abstracts.show(2)
# Out:
# +---------+--------------------+
# |       id|            abstract|
# +---------+--------------------+
# |0704.0001|  A fully differe...|
# |0704.0002|  We describe a n...|
# +---------+--------------------+
# only showing top 2 rows

# %%
df_abstracts.describe()
# Out:
# DataFrame[summary: string, id: string, abstract: string]

# %%
df_categories=df.selectExpr("id","explode(split(categories,' ')) as categories")

# %%
df_categories.show()
# Out:
# +---------+-----------------+
# |       id|       categories|
# +---------+-----------------+
# |0704.0001|           hep-ph|
# |0704.0002|          math.CO|
# |0704.0002|            cs.CG|
# |0704.0003|   physics.gen-ph|
# |0704.0004|          math.CO|
# |0704.0005|          math.CA|
# |0704.0005|          math.FA|
# |0704.0006|cond-mat.mes-hall|
# |0704.0007|            gr-qc|
# |0704.0008|cond-mat.mtrl-sci|
# |0704.0009|         astro-ph|
# |0704.0010|          math.CO|
# |0704.0011|          math.NT|
# |0704.0011|          math.AG|
# |0704.0012|          math.NT|
# |0704.0013|          math.NT|
# |0704.0014|          math.CA|
# |0704.0014|          math.AT|
# |0704.0015|           hep-th|
# |0704.0016|           hep-ph|
# +---------+-----------------+
# only showing top 20 rows

# %%
df_categories.count()
# Out:
# 5000

# %%
#split("letters", ", ")

df.selectExpr("id","explode(split(categories,' ')) as e").show()
# Out:
# +---------+-----------------+
# |       id|                e|
# +---------+-----------------+
# |0704.0001|           hep-ph|
# |0704.0002|          math.CO|
# |0704.0002|            cs.CG|
# |0704.0003|   physics.gen-ph|
# |0704.0004|          math.CO|
# |0704.0005|          math.CA|
# |0704.0005|          math.FA|
# |0704.0006|cond-mat.mes-hall|
# |0704.0007|            gr-qc|
# |0704.0008|cond-mat.mtrl-sci|
# |0704.0009|         astro-ph|
# |0704.0010|          math.CO|
# |0704.0011|          math.NT|
# |0704.0011|          math.AG|
# |0704.0012|          math.NT|
# |0704.0013|          math.NT|
# |0704.0014|          math.CA|
# |0704.0014|          math.AT|
# |0704.0015|           hep-th|
# |0704.0016|           hep-ph|
# +---------+-----------------+
# only showing top 20 rows

# %%
df_versions.withColumn("dd",from_unixtime(col("created"), format='yyyy-MM-dd HH:mm:ss')).show(10)

, regexp_extract(col('Notes'), '(.)(by)(\s+)(\w+)', 4)
# Out:
# +---------+--------------------+-------+----+
# |       id|             created|version|  dd|
# +---------+--------------------+-------+----+
# |0704.0001|Mon, 2 Apr 2007 1...|     v1|null|
# |0704.0001|Tue, 24 Jul 2007 ...|     v2|null|
# |0704.0002|Sat, 31 Mar 2007 ...|     v1|null|
# |0704.0002|Sat, 13 Dec 2008 ...|     v2|null|
# |0704.0003|Sun, 1 Apr 2007 2...|     v1|null|
# |0704.0003|Sat, 8 Dec 2007 2...|     v2|null|
# |0704.0003|Sun, 13 Jan 2008 ...|     v3|null|
# |0704.0004|Sat, 31 Mar 2007 ...|     v1|null|
# |0704.0005|Mon, 2 Apr 2007 1...|     v1|null|
# |0704.0006|Sat, 31 Mar 2007 ...|     v1|null|
# +---------+--------------------+-------+----+
# only showing top 10 rows

# %%
from pyspark.sql.functions import regexp_extract

# %%
df_versions=df_versions.withColumn("mouth", regexp_extract(col('created'), '(,)(\s+)(\w+)(\s+)(\w+)', 5))
df_versions=df_versions.withColumn("year", regexp_extract(col('created'), '(,)(\s+)(\w+)(\s+)(\w+)(\s+)(\w+)', 7))
df_versions.show(10)
# Out:
# +---------+--------------------+-------+-----+----+
# |       id|             created|version|mouth|year|
# +---------+--------------------+-------+-----+----+
# |0704.0001|Mon, 2 Apr 2007 1...|     v1|  Apr|2007|
# |0704.0001|Tue, 24 Jul 2007 ...|     v2|  Jul|2007|
# |0704.0002|Sat, 31 Mar 2007 ...|     v1|  Mar|2007|
# |0704.0002|Sat, 13 Dec 2008 ...|     v2|  Dec|2008|
# |0704.0003|Sun, 1 Apr 2007 2...|     v1|  Apr|2007|
# |0704.0003|Sat, 8 Dec 2007 2...|     v2|  Dec|2007|
# |0704.0003|Sun, 13 Jan 2008 ...|     v3|  Jan|2008|
# |0704.0004|Sat, 31 Mar 2007 ...|     v1|  Mar|2007|
# |0704.0005|Mon, 2 Apr 2007 1...|     v1|  Apr|2007|
# |0704.0006|Sat, 31 Mar 2007 ...|     v1|  Mar|2007|
# +---------+--------------------+-------+-----+----+
# only showing top 10 rows

# %%
df_versions.withColumn("dd", unix_timestamp(df_versions.created,'zzz, dd MMM yyyy HH:mm:ss zzz')   ).show(10)
# Out:
# +---------+--------------------+-------+----------+
# |       id|             created|version|        dd|
# +---------+--------------------+-------+----------+
# |0704.0001|Mon, 2 Apr 2007 1...|     v1|      null|
# |0704.0001|Tue, 24 Jul 2007 ...|     v2|      null|
# |0704.0002|Sat, 31 Mar 2007 ...|     v1|1175307978|
# |0704.0002|Sat, 13 Dec 2008 ...|     v2|1229189160|
# |0704.0003|Sun, 1 Apr 2007 2...|     v1|      null|
# |0704.0003|Sat, 8 Dec 2007 2...|     v2|      null|
# |0704.0003|Sun, 13 Jan 2008 ...|     v3|      null|
# |0704.0004|Sat, 31 Mar 2007 ...|     v1|1175310974|
# |0704.0005|Mon, 2 Apr 2007 1...|     v1|      null|
# |0704.0006|Sat, 31 Mar 2007 ...|     v1|1175315099|
# +---------+--------------------+-------+----------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import col, concat_ws
df_author=df.selectExpr("id","explode(authors_parsed) as e")
df_author=df_author.withColumn("author",concat_ws(" ",col("e")))
df_author=df_author.select("id","author")

# %%
df_author.limit(10).toPandas()
# Out:
#           id               author
# 0  0704.0001  Balázs C.
# 1  0704.0001  Berger E. L.
# 2  0704.0001  Nadolsky P. M.
# 3  0704.0001  Yuan C. -P.
# 4  0704.0002  Streinu Ileana
# 5  0704.0002  Theran Louis
# 6  0704.0003  Pan Hongjun
# 7  0704.0004  Callan David
# 8  0704.0005  Abu-Shammala Wael
# 9  0704.0005  Torchinsky Alberto

# %%
df2 = spark.read.csv('/home/gari/Desktop/final_project/input_data/papers.csv',header=True)

# %%
df2.na.drop().show(10)
# Out:
# +--------------------+------------+--------------------+-----------------+--------------+--------------------+--------------------+
# |                  id|        year|               title|       event_type|      pdf_name|            abstract|          paper_text|
# +--------------------+------------+--------------------+-----------------+--------------+--------------------+--------------------+
# |         Furthermore|  add (x"" y|) to S;-l to prod...|             i.e.|             S|                 = S|          _l U {(x""|
# |       [10] Bachmann|       C. M.|              Cooper|             L. N|         Dembo|       A. & Zeitouni|           O. (to be|
# |             Fregnac|          Y.|               Shulz|               D.|        Thorpe|  S. and Bienenstock| E. A cellular an...|
# |        II p(y; I x;|         DCn|                  j)| Mt}j II p(Y; Ix;|           DCn|                  j)|                 M2)|
# |[Ford et al. 89] ...|         I. |        Titterington|             D.M.|        Kitsos| C.P. (1989): Rec...|                  31|
# |                i.e.| translation|            rotation|         dilation|    elongation|           and shear| do not change th...|
# |for hand-printed ...|       J. E.|              Hanson|            S. J.|  and Lippmann|               R. P.|             editors|
# |              Jacobs|       R. A.|              Jordan|            M. 1.|        Nowlan|               S. J.|          and Hinton|
# |characterize obje...|       R. P.|               Moody|            J. E.| and Touretzky|               D. S.|             editors|
# |              Durbin|       R. M.|               Miall|               c.| and Mitchison|               G. J.|             editors|
# +--------------------+------------+--------------------+-----------------+--------------+--------------------+--------------------+
# only showing top 10 rows

# %%
df2.na.drop().count()
# Out:
# 23701

# %%
df2.na.drop().limit(10).toPandas()
# Out:
#                                                  id          year  \
# 0  Furthermore                                        add (x"" y
# 1  [10] Bachmann                                      C. M.
# 2  Fregnac                                            Y.
# 3  II p(y; I x;                                       DCn
# 4  [Ford et al. 89] Ford                              I.
# 5  i.e.                                               translation
# 6  for hand-printed character recognition. In Moody   J. E.
# 7  Jacobs                                             R. A.
# 8  characterize objects. In Lippmann                  R. P.
# 9  Durbin                                             R. M.
#
#                      title         event_type        pdf_name  \
# 0  ) to S;-l to produce Sa   i.e.               S
# 1   Cooper                   L. N               Dembo
# 2   Shulz                    D.                 Thorpe
# 3  j)                        Mt}j II p(Y; Ix;   DCn
# 4   Titterington             D.M.               Kitsos
# 5   rotation                 dilation           elongation
# 6   Hanson                   S. J.              and Lippmann
# 7   Jordan                   M. 1.              Nowlan
# 8   Moody                    J. E.              and Touretzky
# 9   Miall                    c.                 and Mitchison
#
#                                                            abstract  \
# 0   = S
# 1   A. & Zeitouni
# 2   S. and Bienenstock
# 3  j)
# 4   C.P. (1989): Recent Advances in Nonlinear Design. Technometrics
# 5   and shear
# 6   R. P.
# 7   S. J.
# 8   D. S.
# 9   G. J.
#
#                                                                                                  paper_text
# 0  _l U {(x""
# 1   O. (to be
# 2   E. A cellular analogue of visual cortical plasticity. Nature (Lond.) 333
# 3   M2)
# 4   31
# 5   do not change the underlying shape of an object so we want the deformation energy to be invariant under
# 6   editors
# 7   and Hinton
# 8   editors
# 9   editors

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect('/home/gari/Desktop/final_project/input_data/database.sqlite')

cur = con.cursor()

# The result of a "cursor.execute" can be iterated over by row
for row in cur.execute("pragma table_info('papers')"):
    print(row)
# Out:
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'year', 'INTEGER', 0, None, 0)
# (2, 'title', 'TEXT', 0, None, 0)
# (3, 'event_type', 'TEXT', 0, None, 0)
# (4, 'pdf_name', 'TEXT', 0, None, 0)
# (5, 'abstract', 'TEXT', 0, None, 0)
# (6, 'paper_text', 'TEXT', 0, None, 0)

# %%
for row in cur.execute("select count(*) from papers where abstract != 'Abstract Missing' "):
    print(row)
# Out:
# (3924,)

# %%
for row in cur.execute("pragma table_info('paper_authors')"):
    print(row)
# Out:
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'paper_id', 'INTEGER', 0, None, 0)
# (2, 'author_id', 'INTEGER', 0, None, 0)

# %%
df3 = sqlContext.read.format('jdbc').\
     options(url='jdbc:sqlite:Chinook_Sqlite.sqlite',\
     dbtable='/home/gari/Desktop/final_project/input_data/database.sqlite',driver='org.sqlite.JDBC').load()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-ac7b1c82c42a> in <module>()
# ----> 1 df3 = sqlContext.read.format('jdbc').     options(url='jdbc:sqlite:Chinook_Sqlite.sqlite',     dbtable='/home/gari/Desktop/final_project/input_data/database.sqlite',driver='org.sqlite.JDBC').load()
#
# NameError: name 'sqlContext' is not defined

# %%
import sqlite3
import pandas as pd

db_path = "/home/gari/Desktop/final_project/input_data/database.sqlite"
query = "select id,year ,title,abstract  from papers where abstract != 'Abstract Missing' "

conn = sqlite3.connect(db_path)
a_pandas_df = pd.read_sql_query(query, conn)


#a_spark_df = spark.createDataFrame(a_pandas_df)

# %%
a_pandas_df.to_csv('/home/gari/Desktop/final_project/input_data/NIPS.csv')
